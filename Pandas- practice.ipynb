# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\kapil'

# %%
fifa = pd.read_csv('FIFA_data.csv')

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa.isnull()
# Out:
#        Unnamed: 0     ID   Name    Age  Photo  Nationality   Flag  Overall  \
# 0           False  False  False  False  False        False  False    False
# 1           False  False  False  False  False        False  False    False
# 2           False  False  False  False  False        False  False    False
# 3           False  False  False  False  False        False  False    False
# 4           False  False  False  False  False        False  False    False
# ...           ...    ...    ...    ...    ...          ...    ...      ...
# 18202       False  False  False  False  False        False  False    False
# 18203       False  False  False  False  False        False  False    False
# 18204       False  False  False  False  False        False  False    False
# 18205       False  False  False  False  False        False  False    False
# 18206       False  False  False  False  False        False  False    False
#
#        Potential   Club  ...  Composure  Marking  StandingTackle  \
# ...

# %%
url= 'https://www.basketball-reference.com/leagues/NBA_2016_totals.html'
bb_data= pd.read_html(url)

# %%
bb_data
type(bb_data)
# Out:
# list

# %%
bb_data[0].iloc[ 1:20 , 1:10]
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA
# 1        Jordan Adams  SG  21  MEM   2   0    15    2     6
# 2        Steven Adams   C  22  OKC  80  80  2014  261   426
# 3       Arron Afflalo  SG  30  NYK  71  57  2371  354   799
# 4       Alexis Ajinça   C  27  NOP  59  17   861  150   315
# 5        Cole Aldrich   C  27  LAC  60   5   800  134   225
# 6   LaMarcus Aldridge  PF  30  SAS  74  74  2261  536  1045
# 7     Cliff Alexander  PF  20  POR   8   0    36    5    10
# 8         Lavoy Allen  PF  26  IND  79  28  1599  191   370
# 9          Tony Allen  SG  34  MEM  64  57  1620  215   469
# 10    Al-Farouq Aminu  SF  25  POR  82  82  2341  299   719
# 11       Lou Amundson  PF  33  NYK  29   0   204   19    53
# 12     Chris Andersen   C  37  TOT  27  15   402   38    72
# 13     Chris Andersen   C  37  MIA   7   1    36    4    10
# 14     Chris Andersen   C  37  MEM  20  14   366   34    62
# 15      Alan Anderson  SG  33  WAS  13   0   192   21    59
# ...

# %%
type(fifa)
# Out:
# pandas.core.frame.DataFrame

# %%
fifa['Name']
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
fifa.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
fifa.dtypes == "float64"
# Out:
# Unnamed: 0        False
# ID                False
# Name              False
# Age               False
# Photo             False
#                   ...
# GKHandling         True
# GKKicking          True
# GKPositioning      True
# GKReflexes         True
# Release Clause    False
# Length: 89, dtype: bool

# %%
a= fifa.dtypes[fifa.dtypes == 'object'].index

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
sorted(fifa['Nationality'])[1:20:2]
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania']

# %%
fifa['new_col']='jain'
fifa.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
fifa[['Nationality', 'Name']][4:9]
# Out:
#   Nationality          Name
# 4     Belgium  K. De Bruyne
# 5     Belgium     E. Hazard
# 6     Croatia     L. Modrić
# 7     Uruguay     L. Suárez
# 8       Spain  Sergio Ramos

# %%
fifa[['Name']]
# Out:
#                      Name
# 0                L. Messi
# 1       Cristiano Ronaldo
# 2               Neymar Jr
# 3                  De Gea
# 4            K. De Bruyne
# ...                   ...
# 18202        J. Lundstram
# 18203  N. Christoffersson
# 18204           B. Worman
# 18205      D. Walker-Rice
# 18206           G. Nugent
#
# [18207 rows x 1 columns]

# %%
fifa['new_col']= 'vedang'

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
sorted(fifa['Name'])[5::2]
# Out:
# ['A. Abdulhameed',
#  'A. Abeid',
#  'A. Abrashi',
#  'A. Absalem',
#  'A. Acevedo',
#  'A. Acosta',
#  'A. Adam',
#  'A. Ademi',
#  'A. Adetula',
#  'A. Adomah',
#  'A. Affane',
#  'A. Aguerre',
#  'A. Ahl Holmström',
#  'A. Aidonis',
#  'A. Ajdarević',
#  'A. Ajeti',
#  'A. Akinola',
#  'A. Akkaynak',
#  'A. Al Ammar',
#  'A. Al Arishi',
#  'A. Al Aryani',
#  'A. Al Bahri',
#  'A. Al Basisi',
#  'A. Al Bishi',
#  'A. Al Dakheel',
#  'A. Al Dhafeeri',
#  'A. Al Enazi',
#  'A. Al Faraj',
#  'A. Al Fraidi',
#  'A. Al Ghamdi',
#  'A. Al Habsi',
#  'A. Al Hamdan',
#  'A. Al Hassan',
#  'A. Al Jebreen',
#  'A. Al Khaibari',
#  'A. Al Khaibari',
#  'A. Al Malki',
#  'A. Al Mazaidi',
#  'A. Al Moghir',
#  'A. Al Najjar',
#  'A. Al Nazera',
#  'A. Al Obaid',
#  'A. Al Owayshir',
#  'A. Al Qahtani',
#  'A. Al Riou',
#  'A. Al Sabahi',
#  'A. Al Saleh',
#  'A. Al Saluli',
#  'A. Al Shammari',
#  'A. Al Shammari',
#  'A. Al Shamrani',
#  'A. Al Shehry',
#  'A. Al Sulayhim',
#  'A. Al Yami',
# ...

# %%
fifa[['Name']][5:10]
# Out:
#            Name
# 5     E. Hazard
# 6     L. Modrić
# 7     L. Suárez
# 8  Sergio Ramos
# 9      J. Oblak
